# %% [markdown]
# # 2. Chronological model comparison
#
# Compare linear regression, random forest, and a recent-average baseline on identical later dates. Synthetic-data metrics are a workflow demonstration.

# %%
from pathlib import Path
import sys
root = Path.cwd().resolve()
if root.name == "notebooks":
    root = root.parent
sys.path.insert(0, str(root))
from src.pipeline import load_data, build_features, evaluate
raw = load_data(root / "data/sample_player_games.csv")

# %%
frame, features = build_features(raw, target="points")
report, predictions, models = evaluate(frame, features)
report
# Out:
# {'target': 'points', 'train_rows': 111, 'test_rows': 30, 'train_end': '2025-03-16', 'test_start': '2025-03-18', 'test_end': '2025-04-05', 'seed': 42, 'features': ['points_prior_5', 'reboundsTotal_prior_5', 'assists_prior_5', 'numMinutes_prior_5', 'target_prior_3', 'days_since_last_game', 'game_month', 'game_dayofweek'], 'metrics': {'prior_5_mean': {'mae': 3.8866666666666663, 'rmse': 4.642269559888424}, 'linear_regression': {'mae': 3.8965655653934865, 'rmse': 4.837997920114403}, 'random_forest': {'mae': 3.9604159460909463, 'rmse': 4.718662228571432}}}

# %%
import pandas as pd
pd.DataFrame(report["metrics"]).T
# Out:
#                         mae      rmse
# prior_5_mean       3.886667  4.642270
# linear_regression  3.896566  4.837998
# random_forest      3.960416  4.718662

# %%
predictions.head(10)
# Out:
#        player                  gameDate  ...  linear_regression  random_forest
# 38  Alex Demo 2025-03-18 00:00:00+00:00  ...          18.974885      22.194611
# 39  Alex Demo 2025-03-20 00:00:00+00:00  ...          19.440620      23.466663
# 40  Alex Demo 2025-03-22 00:00:00+00:00  ...          20.537992      22.071943
# 41  Alex Demo 2025-03-24 00:00:00+00:00  ...          18.569616      22.994913
# 42  Alex Demo 2025-03-26 00:00:00+00:00  ...          19.809599      22.569159
# 43  Alex Demo 2025-03-28 00:00:00+00:00  ...          20.488663      21.839318
# 44  Alex Demo 2025-03-30 00:00:00+00:00  ...          23.685674      21.482028
# 45  Alex Demo 2025-04-01 00:00:00+00:00  ...          20.941770      22.534021
# 46  Alex Demo 2025-04-03 00:00:00+00:00  ...          19.358012      22.475463
# 47  Alex Demo 2025-04-05 00:00:00+00:00  ...          19.805911      22.249808
#
# [10 rows x 6 columns]

# %% [markdown]
# ## Interpretation
#
# Lower MAE and RMSE are better on this holdout. A complex model can perform worse than the baseline. Use real data and walk-forward evaluation before drawing conclusions about NBA accuracy.
